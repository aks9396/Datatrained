# %% [markdown]
# # Importing initial Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Uploading our data

# %%
df=pd.read_csv("Auto_Insurance_Claims.csv")

df.head()

# checking top 5 rows
# Out:
#   Customer Country State Code     State  Claim Amount Response  Coverage  \
# 0  BU79786      US         KS    Kansas    276.351928       No     Basic
# 1  QZ44356      US         NE  Nebraska    697.953590       No  Extended
# 2  AI49188      US         OK  Oklahoma   1288.743165       No   Premium
# 3  WW63253      US         MO  Missouri    764.586183       No     Basic
# 4  HB64268      US         KS    Kansas    281.369258       No     Basic
#
#   Education Effective To Date EmploymentStatus  ...  \
# 0  Bachelor           2/24/11         Employed  ...
# 1  Bachelor           1/31/11       Unemployed  ...
# 2  Bachelor           2/19/11         Employed  ...
# 3  Bachelor           1/20/11       Unemployed  ...
# 4  Bachelor            2/3/11         Employed  ...
#
#   Months Since Policy Inception  Number of Open Complaints Number of Policies  \
# 0                             5                          0                  1
# ...

# %%
df.tail()

# checking last 5 rows
# Out:
#      Customer Country State Code     State  Claim Amount Response  Coverage  \
# 9129  LA72316      US         MO  Missouri   2340.598798       No     Basic
# 9130  PK87824      US         MO  Missouri    309.651122      Yes  Extended
# 9131  TD14365      US         MO  Missouri    816.389043       No  Extended
# 9132  UP19263      US         MO  Missouri    752.444244       No  Extended
# 9133  Y167826      US         MO  Missouri    261.183687       No  Extended
#
#      Education Effective To Date EmploymentStatus  ...  \
# 9129  Bachelor           2/10/11         Employed  ...
# 9130   College           2/12/11         Employed  ...
# 9131  Bachelor            2/6/11       Unemployed  ...
# 9132   College            2/3/11         Employed  ...
# 9133   College           2/14/11       Unemployed  ...
#
#      Months Since Policy Inception  Number of Open Complaints  \
# 9129                            89                          0
# ...

# %%
# checking shape of data

df.shape
# Out:
# (9134, 26)

# %%
# looking at the type of data for each column

df.dtypes
# Out:
# Customer                          object
# Country                           object
# State Code                        object
# State                             object
# Claim Amount                     float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Claim Reason                      object
# Sales Channel                     object
# ...

# %%
# To know the name of columns

df.columns
# Out:
# Index(['Customer', 'Country', 'State Code', 'State', 'Claim Amount',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Claim Reason',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
# lets divide columnsin 2 dataframe with respect to types.

df_int = df.select_dtypes(include=[np.number])
df_obj = df.select_dtypes(include=[np.object])
print("df_int----",df_int.columns)
print("df_obj----",df_obj.columns)
# Out:
# df_int---- Index(['Claim Amount', 'Income', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies',
#        'Total Claim Amount'],
#       dtype='object')
# df_obj---- Index(['Customer', 'Country', 'State Code', 'State', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Location Code', 'Marital Status', 'Policy Type', 'Policy',
#        'Claim Reason', 'Sales Channel', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
df.info()

# geting data info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   Country                        9134 non-null   object
#  2   State Code                     9134 non-null   object
#  3   State                          9134 non-null   object
#  4   Claim Amount                   9134 non-null   float64
#  5   Response                       9134 non-null   object
#  6   Coverage                       9134 non-null   object
#  7   Education                      9134 non-null   object
#  8   Effective To Date              9134 non-null   object
#  9   EmploymentStatus               9134 non-null   object
#  10  Gender                         9134 non-null   object
#  11  Income                         9134 non-null   int64
# ...

# %%
# lets check for null values in data

df.isnull().sum()
# Out:
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Claim Amount                     0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
# checking null values graphically

sns.heatmap(df.isnull())

# %% [markdown]
# So there is no null values in our data

# %%
df.nunique()

# to find the unique items in column
# Out:
# Customer                         9134
# Country                             1
# State Code                          5
# State                               5
# Claim Amount                     8041
# Response                            2
# Coverage                            3
# Education                           5
# Effective To Date                  59
# EmploymentStatus                    5
# Gender                              2
# Income                           5694
# Location Code                       3
# Marital Status                      3
# Monthly Premium Auto              202
# Months Since Last Claim            36
# Months Since Policy Inception     100
# Number of Open Complaints           6
# Number of Policies                  9
# Policy Type                         3
# Policy                              9
# Claim Reason                        4
# Sales Channel                       4
# Total Claim Amount               5106
# Vehicle Class                       6
# ...

# %%
# Getting some statistical features of data

df.describe()
# Out:
#        Claim Amount        Income  Monthly Premium Auto  \
# count   9134.000000   9134.000000           9134.000000
# mean     800.494047  37657.380009             93.219291
# std      687.096761  30379.904734             34.407967
# min      189.800768      0.000000             61.000000
# 25%      399.425179      0.000000             68.000000
# 50%      578.018220  33889.500000             83.000000
# 75%      896.216704  62320.000000            109.000000
# max     8332.538119  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# 25%                   6.000000                      24.000000
# 50%                  14.000000                      48.000000
# ...

# %% [markdown]
# From this we can easily see that there is huge difference between the 75 percentile and max values in few columns hence there may be some outliers present in our data.
#
# lets see this by boxplot also

# %%
for i in df_int:
    plt.figure(figsize=(10,5))

    sns.boxplot(df_int[i])

# %% [markdown]
# From the above plots we can see that there are outliers in our data which we will remove after visualisation.

# %%
# Now removing outliers from data.

from scipy import stats
df=df[(np.abs(stats.zscore(df_int)) < 3).all(axis=1)]
print(df.shape)          # old data shape
print(df.shape)        # new data shape
# Out:
# (8470, 26)
# (8470, 26)

# %% [markdown]
# After removing outliers we are left with 8470 Rows now. Almost 664 rows are removed from data.

# %% [markdown]
# # Univariate Analysis

# %%
for i in df_obj:
    plt.figure(figsize=(30,15))
    plt.subplot(321)
    sns.countplot(df_obj[i])

# %% [markdown]
# # Bivariant Analysis

# %%
for i in df_obj:
    sns.catplot(x=i, y='Total Claim Amount',data=df,kind='bar')

# %%
sns.catplot(x='Vehicle Class',y='Total Claim Amount',hue='Vehicle Size',data=df,kind='violin',aspect=2)

# %%
sns.catplot(x='State',y='Total Claim Amount',hue='EmploymentStatus',data=df,kind='boxen',aspect=2)

# %%
sns.catplot(x='State',y='Total Claim Amount',hue='Claim Reason',data=df,kind='bar',aspect=2)

# %%
df_int.skew()
# Out:
# Claim Amount                     1.848796
# Income                           0.282827
# Monthly Premium Auto             1.330466
# Months Since Last Claim          0.283606
# Months Since Policy Inception    0.049470
# Number of Open Complaints        2.574570
# Number of Policies               1.226531
# Total Claim Amount               0.709643
# dtype: float64

# %%
for i in df_int:
    plt.figure(figsize=(8,10))
    sns.distplot(df_int1[i],kde=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-92-25d9433ff193> in <module>
#       1 for i in df_int:
#       2     plt.figure(figsize=(8,10))
# ----> 3     sns.distplot(df_int1[i],kde=True)
#
# ~\Anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# # Preprocessing data

# %%
# let tranform all the column to make it into 1 data type.

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

for col in df_obj:
    df_obj[col] = le.fit_transform(df_obj[col])
    
df_obj.head()
# Out:
# C:\Users\Amit\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#    Customer  Country  State Code  State  Response  Coverage  Education  \
# 0       545        0           1      1         0         0          0
# 1      5504        0           3      3         0         1          0
# 2        88        0           4      4         0         2          0
# 3      7429        0           2      2         0         0          0
# 4      2290        0           1      1         0         0          0
#
#    Effective To Date  EmploymentStatus  Gender  Location Code  Marital Status  \
# 0                 47                 1       0              1               1
# ...

# %%
# now joining the the two data frame into one

df_new=pd.concat([df_int,df_obj],axis=1)

df_new.head()
# Out:
#    Claim Amount  Income  Monthly Premium Auto  Months Since Last Claim  \
# 0    276.351928   56274                    69                       32
# 1    697.953590       0                    94                       13
# 2   1288.743165   48767                   108                       18
# 3    764.586183       0                   106                       18
# 4    281.369258   43836                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies  Total Claim Amount  Customer  Country  ...  \
# 0                   1          384.811147       545        0  ...
# ...

# %%
df_new.dtypes
# Out:
# Claim Amount                     float64
# Income                             int64
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Total Claim Amount               float64
# Customer                           int32
# Country                            int32
# State Code                         int32
# State                              int32
# Response                           int32
# Coverage                           int32
# Education                          int32
# Effective To Date                  int32
# EmploymentStatus                   int32
# Gender                             int32
# Location Code                      int32
# Marital Status                     int32
# Policy Type                        int32
# Policy                             int32
# Claim Reason                       int32
# ...

# %%
df_new.isnull().sum()
# Out:
# Claim Amount                     0
# Income                           0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Total Claim Amount               0
# Customer                         0
# Country                          0
# State Code                       0
# State                            0
# Response                         0
# Coverage                         0
# Education                        0
# Effective To Date                0
# EmploymentStatus                 0
# Gender                           0
# Location Code                    0
# Marital Status                   0
# Policy Type                      0
# Policy                           0
# Claim Reason                     0
# Sales Channel                    0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
# now dividing the data in two parts as inpurt and target

x=df_new.drop(['Total Claim Amount'],axis=1)
print(x.shape)
x.head()
# Out:
# (8470, 25)
#    Claim Amount  Income  Monthly Premium Auto  Months Since Last Claim  \
# 0    276.351928   56274                    69                       32
# 1    697.953590       0                    94                       13
# 2   1288.743165   48767                   108                       18
# 3    764.586183       0                   106                       18
# 4    281.369258   43836                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies  Customer  Country  State Code  ...  EmploymentStatus  \
# 0                   1       545        0           1  ...                 1
# ...

# %%
y= df_new[["Total Claim Amount"]]
print(y.shape)
y.head()
# Out:
# (8470, 1)
#    Total Claim Amount
# 0          384.811147
# 1         1131.464935
# 2          566.472247
# 3          529.881344
# 4          138.130879

# %%
# normalizing the data

from sklearn.preprocessing import StandardScaler
ssc=StandardScaler()
x=ssc.fit_transform(x)

# %% [markdown]
# # Importing Libraries for model selection

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %% [markdown]
# # Train n Test Split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (6352, 25)
# (6352, 1)
# (2118, 25)
# (2118, 1)

# %%
LR=LinearRegression()
LS=Lasso()
RD=Ridge()
KNR=KNeighborsRegressor()
SV=SVR()
DTR=DecisionTreeRegressor()
RFR=RandomForestRegressor()
GBR=GradientBoostingRegressor()
ABR=AdaBoostRegressor()

# %%
# for finding best random state  as parameter

max_r_score=0
for r_state in range(42,101):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.25)
        lr=LinearRegression()
        lr.fit(x_train,y_train)
        y_pred = lr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2_score corresponding to random state ",r_state,"is: ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
print("Max r2 score corresponding to random_state ",final_r_state," is",max_r_score)
# Out:
# r2_score corresponding to random state  42 is:  0.5356533510340544
# r2_score corresponding to random state  43 is:  0.5183737015659672
# r2_score corresponding to random state  44 is:  0.5192052971970929
# r2_score corresponding to random state  45 is:  0.5330753489472118
# r2_score corresponding to random state  46 is:  0.5350445122272323
# r2_score corresponding to random state  47 is:  0.5210714513411681
# r2_score corresponding to random state  48 is:  0.5055200468534347
# r2_score corresponding to random state  49 is:  0.528062624976672
# r2_score corresponding to random state  50 is:  0.5177908953870753
# r2_score corresponding to random state  51 is:  0.523826258013605
# r2_score corresponding to random state  52 is:  0.5033589953235209
# r2_score corresponding to random state  53 is:  0.5297911139698583
# r2_score corresponding to random state  54 is:  0.5394347541620134
# r2_score corresponding to random state  55 is:  0.5215857193848168
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=90)

# %%
models = []
models.append(('LinearRegression', LR))
models.append(('Lasso',LS))
models.append(('Ridge',RD))
models.append(('KNeighborseRegressor',KNR))
models.append(('SVR', SV))
models.append(('DecisionTreeRegressor', DTR))
models.append(('RandomForestRegressor', RFR))
models.append(('GradientBoostingRegressor', GBR))
models.append(('AdaBoostRegressor',ABR))

# %%
Model=[]
R2_score=[]
cvs=[]
MSE=[]
RMSE=[]
for name,model in models:
    print('*********************************',name,'*********************************')
    print('\n',model)
    Model.append(name)
    model.fit(x_train,y_train)
    pred=model.predict(x_test)
    
    r2_scr=r2_score(y_test,pred)
    print('R2_score = ',r2_scr)
    R2_score.append(r2_scr)
    
    mse=mean_squared_error(y_test,pred)
    print("Mean_Squared_Error =",mse)
    MSE.append(mse)
    
    rmse=np.sqrt(mean_squared_error(y_test,pred))
    print("Root Mean Square Error = ",rmse)
    RMSE.append(rmse) 
    
    
    score= cross_val_score(model,x,y,cv=10,scoring='r2').mean()
    print('Cross_Val_Score = ',score)
    cvs.append(score)
    print('\n\n')
# Out:
# ********************************* LinearRegression *********************************
#
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# R2_score =  0.5541336375378283
# Mean_Squared_Error = 23924.355592752734
# Root Mean Square Error =  154.674999895758
# Cross_Val_Score =  0.524850218894888
#
#
#
# ********************************* Lasso *********************************
#
#  Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)
# R2_score =  0.5545274581873408
# Mean_Squared_Error = 23903.223912832596
# Root Mean Square Error =  154.6066748650672
# Cross_Val_Score =  0.5250477862160806
#
#
#
# ********************************* Ridge *********************************
#
#  Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
# ...

# %%
result = pd.DataFrame({'Model': Model, 'R2_score': R2_score ,'Mean_Squared_Error' :MSE,'Root Mean Square Error': RMSE, 'Cross_val_score':cvs})
result
# Out:
#                        Model  R2_score  Mean_Squared_Error  \
# 0           LinearRegression  0.554134        23924.355593
# 1                      Lasso  0.554527        23903.223913
# 2                      Ridge  0.554131        23924.494495
# 3       KNeighborseRegressor  0.601852        21363.853000
# 4                        SVR  0.274691        38918.742545
# 5      DecisionTreeRegressor  0.651466        18701.697655
# 6      RandomForestRegressor  0.840232         8572.827029
# 7  GradientBoostingRegressor  0.835241         8840.686666
# 8          AdaBoostRegressor  0.713198        15389.257542
#
#    Root Mean Square Error  Cross_val_score
# 0              154.675000         0.524850
# 1              154.606675         0.525048
# 2              154.675449         0.524848
# 3              146.163788         0.609753
# 4              197.278338         0.296135
# 5              136.754150         0.660283
# 6               92.589562         0.831166
# ...

# %% [markdown]
# we can slect Random Forest regressor as our final model asi t has the highest r2 score

# %%
# for saving our model

from sklearn.externals import joblib
joblib.dump(RFR,"Automobile_insurance_claim")
# Out:
# C:\Users\Amit\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# ['Automobile_insurance_claim']

# %%
# testing our model

model=joblib.load("Automobile_insurance_claim")
model.predict(x_test)
# Out:
# array([487.52929096, 378.80985978, 520.18710011, ..., 110.34066044,
#        334.48622524, 526.84681192])

# %% [markdown]
# # Complete
